# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonall2023/Capstone_EDA_Hotel_booking/blob/main/Final_Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -Hotel Booking Analysis

# %% [markdown]
# **Project Type**    - EDA
#
#
# **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things.
#
# Here is a project summary for hotel booking analysis:
#
# • **Project Goal**: The goal of this project is to analyse hotel booking data to identify trends and patterns that can be used to improve hotel operations.
#
# • **Data**: The data for this project is a publicly available dataset of hotel bookings from 2015 to 2017. The dataset contains information on the booking date, hotel type, room type, number of guests, length of stay, and deposit amount. There are 32 columns and 119390 rows in data frames
#
# • **Methods**: The data will be analysed using exploratory data analysis (EDA) techniques. EDA is a process of inspecting data to summarize its main features, identify patterns, and discover anomalies.
#
# This project is a great way to learn about the hotel industry and how to use data analysis to improve business performance. The findings of this project could be used by hotels to make better decisions about marketing, pricing, and operations
#
# ![download.webp](data:image/webp;base64,...)

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Sonall2023/Capstone_EDA_Hotel_booking/blob/main/Hotel_Booking_Analysis.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In this project, I’m going to analyse hotel booking data to identify trends and patterns that can be used to improve marketing, pricing, and operations. The goal of this project is to analyse hotel booking data to identify factors that influence booking demand. The findings of this project will be used to make recommendations for improving hotel operations.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of hotel booking analysis is to improve the performance of a hotel by identifying trends and patterns in booking data. This can be used to make better decisions about marketing, pricing, increasing bookings, optimize pricing, reduce cancellations and operations.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries
#
# Firstly, we shall import the required python libraries.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading
# Here, We are reading a csv file .

# %%
# connect google drive with google colab
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/MyDrive/Hotel_df/Hotel Bookings (3).csv"
Hotel_df = pd.read_csv(file_path)

# %% [markdown]
# ### **Dataset First View**
# Let's take a closer look at the features, values, and structure of the Hotel Database dataset.

# %%
#Viewing Hotel_Booking dataframe
Hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# There are  119390 rows and 32 columns in the Dataset.

# %%
#Viewing the available numeric column details
Hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# We, confidently generate and display summary statistics for our Dataset.

# %%
#Renaming the 'adr' column name to 'Average_daily_rate' for understanding the data well.
Hotel_df.rename(columns ={'adr' : 'Average_daily_rate'},inplace =True)
Hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# Total index in the dataset
Hotel_df.index
# Out:
# RangeIndex(start=0, stop=119390, step=1)

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Counting rows and columns in dataframe using shape
# Dataset Rows count
Numbers_of_rows = Hotel_df.shape[0]
Numbers_of_rows
# Out:
# 119390

# %%
# Dataset Columns count
Numbers_of_s_columns = Hotel_df.shape[1]
Numbers_of_s_columns
# Out:
# 32

# %% [markdown]
# **Dataset Information**

# %%
# Dataset Info
Hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Duplicate Values
Duplicate_values = Hotel_df.duplicated().sum()
print("Number of duplicate values:", Duplicate_values)
# Out:
# Number of duplicate values: 31994

# %% [markdown]
# Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("Columns and their missing values:")
Hotel_df.isnull().sum()
# Out:
# Columns and their missing values:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# ...

# %%
# Visualizing the missing values
import matplotlib.pyplot as plt

#missing_values_columns and percentage of missing values in the columns
missing_columns = ['country', 'agent','company']
missing_values_percentage = (Hotel_df[missing_columns].isnull().mean())*100

#chnage the colour of bars
bar_colors = ['blue', 'orange', 'green']

#Bar_chart to visulaize the missing values in column
plt.bar(missing_columns, missing_values_percentage,color = bar_colors)

#Labels and titles of Bar_chart
plt.xlabel('Missing_values_Columns')
plt.ylabel('Percentage of Missing Values')
plt.title('Percentage of Missing Values in Columns')
plt.show()

# %% [markdown]
# **What did you know about your dataset?**
#
# We have a dataset of  119390 hotel bookings that has some missing data in important columns like 'country', 'agent', and 'company'. To gain valuable insights into booking patterns and customer behaviour, we need to do thorough exploratory analysis. This analysis will help us understand cancellation trends, seasonal booking patterns, preferred room types, and customer segments in detail. Before starting the analysis, we must handle the missing data correctly and do necessary data pre-processing. We need to drop duplicates values form the dataset.
# Once we handle the missing values, we can dig into the data to find interesting patterns and trends. We'll be able to see things like when most people book their stays, which months are busier for the hotel, and how long people usually wait between booking and arriving. We can also find out which type of hotel room is the most popular and what kind of guests visit the hotel the most.By doing this, we'll gain valuable insights that can help the hotel make better decisions and improve their services for guests. But, it's essential to start by cleaning the data and making sure everything is accurate and reliable, so our analysis is based on solid information
# By gaining accurate insights through this process, hotels can make better decisions and improve their services.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Describe
# Dataset Columns
Hotel_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type',
#        'Average_daily_rate', 'required_car_parking_spaces',
#        'total_of_special_requests', 'reservation_status',
#        'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
Hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# Here, we can quickly overview the distribution of a dataset.

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1.	hotel - This column represents the type of hotel
# 2.	is_canceled: This variable indicates whether a booking was cancelled or not . The description could mention the cancellation rate based on the mean value and highlight the proportion of cancelled bookings.
# 3.	lead_time: The number of days between the booking date and the arrival date. The description could discuss the average lead time and whether there are any extreme values that might need further investigation.
# 4.	arrival_date_year: The year of the arrival date. The description could mention the range of years present in the dataset and any trends observed over the years.
# 5.	arrival_date_week_number: The week number of the year for the arrival date. The description could mention any patterns in booking frequency based on the week number.
# 6.	arrival_date_day_of_month: The day of the month for the arrival date. The description could discuss any patterns related to specific days of the month.
# 7.	stays_in_weekend_nights: The number of weekend nights the guest stayed or booked to stay at the hotel. The description could mention the average number of weekend nights and whether weekend stays are more common.
# 8.	stays_in_week_nights: The number of weekday nights the guest stayed or booked to stay at the hotel. The description could discuss the average number of weekday nights and the overall length of stays.
# 9.	adults, children, babies: These columns represent the number of adults, children, and babies in the booking, respectively. The description could discuss the typical group size of guests (average values) and any variations in the number of children and babies.
# 10.	is_repeated_guest: This column indicates if the guest is a repeated guest or not. The description could discuss the proportion of repeated guests and their potential impact on bookings.
# 11.	previous_cancellations: The number of previous bookings canceled by the guest. The description could discuss the frequency of previous cancellations and its relevance to current bookings.
# 12.	previous_bookings_not_canceled: The number of previous bookings not canceled by the guest. The description could mention any patterns in guests' history of not canceling bookings.
# 13.	booking_changes: The number of changes made to the booking. The description could discuss the frequency of booking modifications and their impact on cancellations.
# 14.	agent : This columns represent the money received by the agent. the description represents the percentage of money. highest rate and lowest rate of the agent.
# 15.	company - This column reprent the total money. max money, lowest money and mean money received by the company and also represents the trends to analyse the profit and loss structure
# 16.	days_in_waiting_list: The number of days the booking was in the waiting list before confirmed. The description could discuss the average waiting time and any patterns related to waitlisted bookings.
# 17.	adr: The average daily rate of the booking. The description could discuss the average cost per night and any variations in pricing.
# 18.	required_car_parking_spaces: The number of car parking spaces required by the guest. The description could discuss the need for parking spaces among guests.
# 19.	total_of_special_requests: The total number of special requests made by the guest. The description could discuss the frequency of special requests and the most common types of requests.
# 20.	meal: This column represents the type of meal booked (e.g., Bed & Breakfast, Half-board, etc.). The description could discuss the different meal types and their popularity among guests.
# 21.	country: This column contains the country code of the guests. The description could mention the number of unique countries represented in the dataset and any insights into the distribution of guests from different countries.
# 22.	market_segment: This column represents the market segment designation (e.g., Online Travel Agent, Corporate, etc.). The description could discuss the most common market segments and their significance.
# 23.	distribution_channel: This column indicates the booking distribution channel (e.g., Direct, Travel Agent). The description could mention the different distribution channels and their usage.
# 24.	reserved_room_type: This column represents the type of room reserved. The description could discuss the different room types and their popularity among guests.
# 25.	assigned_room_type: This column represents the type of room actually assigned to the guest. The description could discuss any differences between reserved and assigned room types.
# 26.	deposit_type: This column indicates the type of deposit made for the booking (e.g., No Deposit, Non-Refundable). The description could discuss the proportion of different deposit types and their relationship with cancellations.
# 27.	customer_type: This column represents the type of customer (e.g., Transient, Contract, Group). The description could discuss the distribution of customer types and their booking behavior.
# 28.	reservation_status: This column indicates the status of the reservation (e.g., Check-Out, Canceled, No-Show). The description could discuss the distribution of reservation statuses and any insights related to cancellations or no-shows.
# 29.	reservation_status_date: This column represents the date on which the reservation status was set. The description could discuss any patterns related to reservation status changes over time.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable. - # Understand the unique values in the dataframe to understand the data
Hotel_df['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
Hotel_df['is_canceled'].unique()
# Out:
# array([0, 1])

# %%
Hotel_df['arrival_date_year'].unique()
# Out:
# array([2015, 2016, 2017])

# %%
Hotel_df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
Hotel_df['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
Hotel_df['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
Hotel_df['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
Hotel_df['is_repeated_guest'].unique()
# Out:
# array([0, 1])

# %%
Hotel_df['customer_type'].unique()
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
Hotel_df['deposit_type'].unique()
# Out:
# array(['No Deposit', 'Refundable', 'Non Refund'], dtype=object)

# %%
Hotel_df['reservation_status'].unique()
# Out:
# array(['Check-Out', 'Canceled', 'No-Show'], dtype=object)

# %% [markdown]
# ## 3. ***Data Wrangling***
#
# Upon receiving the hotel booking dataset, we identified several notable issues that required our attention. The dataset contained 119,390 rows and 32 columns, but some critical columns like 'country,' 'agent,' and 'company' had incomplete data and duplicate entries, which hindered our ability to perform a thorough analysis. Therefore, we took immediate action to clean up the data and ensure the accuracy of our analysis.
#
# To clean up the data, we need to remove any duplicate rows.
#
# We should also handle any missing values that may be present.
#
#  It's important to make sure that each column is in the appropriate datatype.
#
#  Additionally, we should add two important columns: total guests and total nights stayed.

# %% [markdown]
# ### Data Wrangling Code

# %%
#Removing Duplicate valuse
Hotel_df[Hotel_df.duplicated()].shape
# Out:
# (31994, 32)

# %% [markdown]
# To guarantee precise data analysis, it's essential to identify and count the exact number of duplicated rows in the dataset.

# %%
# Removing Duplicate values
Hotel_df.drop_duplicates(inplace=True)
Hotel_df.shape
# Out:
# (87396, 32)

# %% [markdown]
# Handling Missing values

# %%
# Total number of missing values in the DataFrame
Hotel_df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# I am correcting any missing or inaccurate data for the company or agent by accurately replacing it with the necessary value of 0.
Hotel_df['company'].fillna(0, inplace=True)
Hotel_df['agent'].fillna(0, inplace=True)

# Replacing the missing_values in country column with 'Unknown'
Hotel_df['country'].fillna('Unknown', inplace=True)

# %% [markdown]
# Null values were discovered in the 'company' and 'agent' columns for certain hotel bookings. In order to preserve data integrity, these missing values will be replaced with 0. Furthermore, the 'country' column has missing values that will be replaced with 'Unknown.

# %%
Hotel_df['children'].fillna(Hotel_df['children'].mean(), inplace = True)

# %% [markdown]
# 4 null values in children column will be replaced with the mean value of the column.

# %%
#Checking the all null_values are removed or not
Hotel_df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# It is clear, that the dataset being reviewed does not have any null values.

# %% [markdown]
# # checking the sum of adults, children and babies is zero or not

# %%
Hotel_df[Hotel_df['adults']+Hotel_df['babies']+Hotel_df['children'] == 0].shape
# Out:
# (166, 32)

# %% [markdown]
# We have identified 166 rows in which the total number of adults, children, and babies is zero. As a result, we will be removing these rows.

# %%
Hotel_df.drop(Hotel_df[Hotel_df['adults']+Hotel_df['babies']+Hotel_df['children'] == 0].index, inplace = True)

# %% [markdown]
#  **Convert columns to appropriate datatypes**

# %%
#Converting datatype of columns 'children', 'company' and 'agent' from float to int.
Hotel_df['children'] = Hotel_df['children'].astype(int)
Hotel_df['company'] = Hotel_df['company'].astype(int)
Hotel_df['agent'] = Hotel_df['agent'].astype(int)

# %%
# Convert date columns to datetime data type
Hotel_df['reservation_status_date'] = pd.to_datetime(Hotel_df['reservation_status_date'])

# %%
# Adding total_guests column = adults + children + babies
Hotel_df['total_guests'] = Hotel_df['adults'] + Hotel_df['children'] + Hotel_df['babies']

# %%
# Adding total_nights_stayed = stayed in weekend nights + stayed in week nights
Hotel_df['total_nights_stayed'] = Hotel_df['stays_in_weekend_nights'] + Hotel_df['stays_in_week_nights']
Hotel_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type',
#        'Average_daily_rate', 'required_car_parking_spaces',
#        'total_of_special_requests', 'reservation_status',
#        'reservation_status_date', 'total_nights_stayed'],
#       dtype='object')

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# We analyzed hotel bookings using advanced data techniques to prepare the dataset for examination. Our approach involved several steps to ensure the accuracy and reliability of our data.
#
# Firstly, we removed duplicate rows to focus on individual booking records and eliminate unnecessary redundancy. Secondly, we addressed the issue of missing data in columns such as 'country', 'agent', and 'company'. For 'country', we retained the missing values as they represented situations where customers did not specify a country during the booking process. However, for 'agent' and 'company', we filled in the gaps with 0 to show that those bookings were not made through any particular agent or company.
#
# We converted the 'children', 'company', and 'agent' columns from float to integer data types since they represented whole numbers. This change allowed us to work with these columns more effectively in our later analyses.
#
# We added two new columns, 'total guests' and 'total nights stayed', to acquire additional insights into booking patterns. By adding up the number of 'adults', 'children', and 'babies', we calculated the total number of guests for each booking. Similarly, we derived the overall nights stayed by combining 'stays_in_weekend_nights' and 'stays_in_week_nights'.
#
# Our approach was highly effective, and we are confident in the accuracy and reliability of our dataset for further analysis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#custom colors for the bars
colors = ['Green', 'Blue']

# bar plot with custom colors
plt.bar(Hotel_df['hotel'].value_counts().index,Hotel_df['hotel'].value_counts().values, color=colors)
plt.xlabel('Hotel Type')
plt.ylabel('Number of Bookings')
plt.title('Distribution of Bookings by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used a bar chart to show booking distribution by hotel type. It's simple and efficient, making it easy to compare the number of reservations in City and Resort Hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City Hotels received over 50,000 bookings, while Resort Hotels received only 30-40,000. This implies that City Hotels are more favored by customers and suggests higher demand and popularity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By focusing on City Hotels' popularity, services, and marketing, business impact can be positive. Bookings for Resort Hotels were lower, so more marketing, discounts, and improved services may be necessary. Replicating successful aspects of City Hotels in Resort Hotels could increase bookings.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Revenue_Based_Analysis
Hotel_df.columns

# Grouping by hotel and calculating average adr
grouped_by_hotel = Hotel_df.groupby('hotel')
avg_adr_by_hotel = grouped_by_hotel['Average_daily_rate'].mean().reset_index()

# Creating the bar plot
plt.figure(figsize=(6, 4))
sns.barplot(x='hotel', y='Average_daily_rate', data=avg_adr_by_hotel, palette=['Brown', 'lightgreen'])
plt.xlabel('Hotel Type')
plt.ylabel('Average Daily Rate (ADR)')
plt.title('Average Daily Rate (ADR) by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the specific bar chart to compare the average daily rate (ADR) between the two types of hotels (City Hotel and Resort Hotel) because it provides a clear and visual representation of the ADR for each category, making it easy to find out which hotel is making more revenue.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City Hotel charges slightly more per day than Resort Hotel, as shown in the bar chart. This means City Hotel earns slightly more revenue on average.

# %% [markdown]
#  3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart helps hotels with pricing and revenue. City Hotel can be more luxurious to attract high-paying guests. Resort Hotel can market its location and family-friendly facilities for affordable vacations. Resort Hotel needs more bookings to make more money.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Distribution of hotel bookings based on the market segment.
plt.figure(figsize=(12, 6))
# Plot for City Hotel bookings by market segment
plt.subplot(1, 2, 1)
sns.countplot(x='market_segment', data=Hotel_df[Hotel_df['hotel'] == 'City Hotel'], palette='pastel')
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.title('City Hotel - Bookings by Market Segment')
plt.xticks(rotation=45, ha='right')

# Plot for Resort Hotel bookings by market segment
plt.subplot(1, 2, 2)
sns.countplot(x='market_segment', data=Hotel_df[Hotel_df['hotel'] == 'Resort Hotel'], palette='pastel')
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.title('Resort Hotel - Bookings by Market Segment')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked two bar charts to compare bookings for different hotel types and market segments. This helps me see patterns and differences between City and Resort Hotels. It shows which market segments are popular and any disparities. This helps make decisions, marketing strategies, and understand customer preferences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that online travel agencies make the most bookings in both types of hotels. City hotels receive around 40,000 bookings from online travel agencies. Corporate bookings are low in both hotels. Resort hotels have fewer bookings from offline travel agencies and groups compared to city hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Insights can help hotels improve business. Online bookings are popular, so hotels should enhance their online presence and partnerships with online travel agencies. Low corporate bookings suggest hotels should offer special packages and improve facilities for business travelers. Few offline TA/TO bookings in resort hotels suggest hotels should collaborate more closely and offer attractive packages. Few group bookings in resort hotels suggest hotels should implement group discounts and promote group-friendly activities.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#distribution of lead time for both hotel types

lead_time_data = Hotel_df[['hotel', 'lead_time']]

# Plotting the distribution of lead time for each hotel type
plt.figure(figsize=(10, 6))
sns.boxplot(x='hotel', y='lead_time', data=lead_time_data, palette='pastel')
plt.xlabel('Hotel Type')
plt.ylabel('Lead Time (Days)')
plt.title('Distribution of Lead Time for City and Resort Hotels')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used a box plot to study how long it takes to book different types of hotels (city and resort). This graph shows the range of data, including the middle value, quarters, and possible unusual results. By comparing the box plots for each group, we can see if there are any differences in how people book these types of hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotels are booked slightly earlier than resort hotels, with a median lead time that is a bit higher. The middle 50% of lead times for both hotel types fall within a range of about 100 days, indicating that most bookings are made within a similar timeframe. City hotels have more outliers on the upper side of the box plot, suggesting that some customers book well in advance due to high demand or specific events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# The chart can help hotels make more money. City hotels usually have longer booking times and more expensive rooms. Hotels can offer discounts or promotions to encourage people to book early. This will help hotels plan better and have more guests.
#
# Neagtive Business Impact
#  The chart shows that city hotels may have last-minute bookings due to competition and flexible travel plans. This could lead to negative growth if hotels don't differentiate themselves or give reasons to book early. Both hotel types have a limited range of 100 days, which could lead to overbooking during peak seasons. To avoid negative guest experiences, hotels need to monitor bookings, forecast demand, and use good reservation management systems.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Calculate the percentage of canceled bookings for each hotel type
total_bookings_by_hotel = Hotel_df.groupby('hotel')['is_canceled'].count()
canceled_bookings_by_hotel = Hotel_df.groupby('hotel')['is_canceled'].sum()
percentage_canceled = (canceled_bookings_by_hotel / total_bookings_by_hotel) * 100
# Create a DataFrame to store the data
cancellation_data = pd.DataFrame({'Hotel Type': percentage_canceled.index,'Percentage Canceled': percentage_canceled.values})
# Plot the bar chart
sns.barplot(x='Hotel Type',y='Percentage Canceled',data=cancellation_data,color='red')
plt.xlabel('Hotel Type')
plt.ylabel('Percentage of Canceled Bookings')
plt.title('Percentage of Canceled Bookings by Hotel Type')
plt.show()

cancellation_data
# Out:
#      Hotel Type  Percentage Canceled
# 0    City Hotel            30.099110
# 1  Resort Hotel            23.483331

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart to show the percentage of cancelled bookings for city and resort hotels. It's easy to compare the two types of hotels and see any patterns or trends. The chart helps us quickly understand the impact of cancellations on each hotel type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City Hotel has a cancellation rate of 41.79%, while Resort Hotel has a rate of 27.77%. This suggests that more bookings are being canceled at City Hotel, possibly due to factors unique to the hotel. Resort Hotel's lower cancellation rate may be due to guests having more fixed vacation plans.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# The City Hotel can benefit from analyzing why guests cancel their bookings. The marketing team can then create promotions to attract more committed guests. Addressing customer concerns can improve guest satisfaction and loyalty. Fewer cancellations mean more guaranteed bookings, which can increase revenue stability and predictability.
#
# Neagtive Business Impact:
# City Hotel's high cancellation rate may cause negative growth. This can result in revenue loss, operational difficulties, and reputation damage. It is important to address this issue to avoid these potential negative impacts.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# Calculate the percentage of each meal type in the dataset
meal_counts = Hotel_df['meal'].value_counts(normalize=True) * 100
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(meal_counts, labels=meal_counts.index, autopct='%1.1f%%',colors=['lightgreen', 'skyblue', 'lightcoral', 'orange', 'pink'])
plt.title('Distribution of Bookings by Meal Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a pie chart to show how bookings are divided among meal types. It's easy to see which meals are popular just by looking at the chart. Each slice represents a meal type and its size shows how much of the bookings it makes up. Labels on the slices help to understand each category. A pie chart also helps to spot any big differences in meal types and which ones are more or less popular.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most guests (77.4%) chose "Bed and Breakfast" (BB) meal plan, followed by "Half Board" (HB) at 12.1%. "Self Catering" (SC) was chosen by 8.8% of guests. Some bookings (1%) had no meal plan specified. "Full Board" (FB) was the least popular, chosen by only 0.7% of guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business:
# Hotels can improve guest satisfaction and loyalty by focusing on quality breakfast options, as most guests prefer the "Bed and Breakfast" meal plan. This can also reduce wastage and operational costs, and targeted promotions for popular meal plans can increase revenue.
#
# Neagtive Business Impact:
# The pie chart doesn't show anything that causes negative growth. But, if there are a few guests who don't specify their meal preferences, it could cause problems with planning and cost more money.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Distribution of bookings based on the "reserved_room_type"
# Plotting the count plot
plt.figure(figsize=(10, 6))
sns.countplot(x='reserved_room_type', hue='hotel', data=Hotel_df, palette='PiYG')
plt.xlabel('Reserved Room Type')
plt.ylabel('Number of Bookings')
plt.title('Distribution of Bookings by Reserved Room Type')
plt.legend(title='Hotel Type', loc='upper right', labels=['Resort Hotel', 'City Hotel'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# The count plot was picked to show how many bookings were made for each room type. It's good for showing categorical data like room types and helps people understand which ones are popular. This helps people make decisions about managing rooms, pricing, and promotions. This can make the business better by making more money and keeping customers happy.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most customers prefer room type 'A' in both City Hotel and Resort Hotel. In City Hotel, the second most popular choice is room type 'D', while in Resort Hotel, it is room type 'D' followed by room type 'E'. Room types 'F', 'G', and 'E' are also booked frequently. Some room types are only available in one hotel, such as 'H', 'L', and 'C' in Resort Hotel and 'B' in both hotels with few bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotels can manage their inventory by stocking up on the most preferred room types to meet demand. They can also set prices based on popularity, offering deals for less popular rooms. This information can be used for targeted marketing and resource allocation, prioritizing maintenance and renovation of popular rooms to attract more guests

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Distribution of the number of stays in weekend nights and stays in week nights separately for both city hotels and resort hotels using Box Plots

# Filter data for city hotels and resort hotels
city_hotel_data = Hotel_df[Hotel_df['hotel'] == 'City Hotel']
resort_hotel_data = Hotel_df[Hotel_df['hotel'] == 'Resort Hotel']

# Create box plot for stays in weekend nights
plt.figure(figsize=(8, 6))
sns.boxplot(x='hotel', y='stays_in_weekend_nights', data=Hotel_df, palette='Set1')
plt.xlabel('Hotel Type')
plt.ylabel('Stays in Weekend Nights')
plt.title('Distribution of Stays in Weekend Nights for City and Resort Hotels')
plt.show()

# Create box plot for stays in week nights
plt.figure(figsize=(8, 6))
sns.boxplot(x='hotel', y='stays_in_week_nights', data=Hotel_df, palette='PiYG')
plt.xlabel('Hotel Type')
plt.ylabel('Stays in Week Nights')
plt.title('Distribution of Stays in Week Nights for City and Resort Hotels')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used box plots to compare the number of stays in weekend and week nights for city and resort hotels. This helps us see differences and outliers, and understand if there are significant variations between hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most hotel bookings for weekend nights are 2 nights or less, shown by the box below 2.5 for both city and resort hotels. However, resort hotels have more outliers with stays over 17.5 nights, possibly for extended vacations or events. This presents a marketing opportunity.
#
# Most bookings for both city and resort hotels have stays of 5 nights or less during weekdays. City hotels have slightly shorter median stays. Resort hotels attract longer weekday stays, which could be targeted by marketing teams.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Box plots help hotels understand guest booking patterns. Targeted marketing can attract longer weekend stays, increasing revenue. Promotions for extended weekday stays can attract business travelers, increasing bookings and customer loyalty.
#
# Negtive Business Impact:
# Long stays on weekends and weekdays may be due to booking errors or data issues. Hotels should review to avoid customer dissatisfaction.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Top 10 countries with the Most Guests
# Grouping data by country and calculating total guests from each country
guests_by_country = Hotel_df.groupby('country')['total_guests'].sum().reset_index()
# Sorting data in descending order of total guests
guests_by_country = guests_by_country.sort_values(by='total_guests', ascending=False)
# Plotting the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='total_guests', data=guests_by_country.head(10))
plt.xlabel('Country')
plt.ylabel('Total Guests')
plt.title('Top 10 Countries with the Most Guests')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart to show how many guests came from each country. It's good for comparing countries quickly. The bars show which countries had the most guests. I only showed the top 10 countries to make it easier to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Portugal is the most popular tourist destination with over 80,000 bookings. The UK and France have 20,000+ bookings, while Spain, Germany, Italy, and Ireland have fewer. Belgium, Brazil, and the USA have the lowest bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Portuguese, British, and French guests are numerous. Hotels can benefit by providing tailored promotions and services to these markets.
#
# Insights that may lead to negative growth:
#
# The lower number of guests from countries like Germany, Italy, Ireland, Belgium, Brazil, and the USA may suggest challenges in attracting guests from these regions. Hotels may need to explore marketing strategies or tailored offerings to attract guests from these countries and drive growth.

# %% [markdown]
# Chart - 10

# %%
# Chart - 10 visualization code
# Top 10 agents who made the highest number of bookings
# Group data by agent and calculate the number of bookings made by each agent
agent_bookings = Hotel_df['agent'].value_counts().reset_index()
agent_bookings.columns = ['agent', 'num_bookings']
# Sort agents by the number of bookings in descending order
agent_bookings = agent_bookings.sort_values(by='num_bookings', ascending=False)
# Select the top 10 agents with the highest number of bookings
top_10_agents = agent_bookings.head(10)
# Plot the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x='agent', y='num_bookings', data=top_10_agents, palette='pastel')
plt.xlabel('Agent')
plt.ylabel('Number of Bookings')
plt.title('Top 10 Agents with Highest Number of Bookings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used a bar chart to show the top 10 agents with the most bookings. It's good for comparing agents and seeing who has the most bookings. The bars show how many bookings each agent has, so it's easy to see who's doing well.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Top 10 agents in the hotel industry with highest bookings. Agent ID 9 has over 25,000 bookings and is the top performer. Agents 240 and 0 have over 10,000 bookings. Other agents have bookings below 5,000 but are performing well.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This chart can help improve business. Focus on top agents (ID 9, 240, 0) to build better relationships and offer incentives. This can lead to more bookings and revenue.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
#Plotting a count plot for distribution channels in terms of the number of booking cancellations
plt.figure(figsize=(12,6))
plot=plt.subplot(111)
ax=sns.countplot(x=Hotel_df['distribution_channel'], hue=Hotel_df['is_canceled'])
ax.set_title('% of booking cancellations per distribution channel')
plt.show()

# %% [markdown]
# The majority of canceled bookings were made through the TA/TO distribution channel. Bookings made through the Direct, Corporate, and GDS distribution channels are extremely unlikely to be canceled.

# %% [markdown]
# #### Chart - 12

# %%
#Deposit type in hotel
plt.figure(figsize = (12,6))
ax = sns.countplot(x = 'deposit_type',hue='hotel' ,palette='pastel',data=Hotel_df)
ax.set_xlabel('Deposite type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I made a Bar chart for hotel types to display the count of no deposit, refundable, and non-refundable bookings..

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel has high no deposit and non-refundable ratio. This indicates that many people have booked resort hotels and are interested in staying there.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# City Hotel should analyze why bookings are low. Marketing can create promotions to attract committed guests. Addressing customer concerns improves satisfaction, loyalty, and revenue.
#
# Negative Business Impact:
# Fewer bookings at City Hotel could lead to revenue loss, operational problems, and harm to its reputation. It's crucial to tackle this issue to prevent these negative consequences.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
 #total revenue for both types of hotel

# Grouping the data by hotel type and calculating the total revenue
revenue_by_hotel = Hotel_df.groupby('hotel')['Average_daily_rate'].mean().reset_index()

# Sorting the data by total revenue in descending order
revenue_by_hotel = revenue_by_hotel.sort_values(by='Average_daily_rate', ascending=False)

# Plotting the bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x='hotel', y='Average_daily_rate', data=revenue_by_hotel, palette='pastel')
plt.xlabel('Hotel Type')
plt.ylabel('Total Revenue')
plt.title('Total Revenue by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the bar chart to visualize the total revenue by hotel type because it effectively compares the revenue generated by each type of hotel in a clear and straightforward manner. The bar chart allows for easy comparison between the two categories (City Hotel and Resort Hotel) and helps identify any significant differences in revenue.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart, we can observe that the revenue generated by the City Hotel is higher than the revenue generated by the Resort .re

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact: The insight that both types of hotels are generating substantial revenue indicates a positive business impact. It suggests that there is a strong demand for accommodations in both city and resort locations, leading to successful revenue generation for the hotels.
#
# Negative Growth: Based on the provided data, there is no insight suggesting negative growth for either hotel type. Both hotels are performing well in terms of revenue generation, and there are no indicators of declining revenue at this point.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Selecting numerical columns for correlation analysis
numerical_columns = Hotel_df.select_dtypes(include=[np.number])

# Calculating the correlation matrix
correlation_matrix = numerical_columns.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Columns")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap shows how numerical variables in the dataset are related. It helps us understand the strength and direction of these relationships. This is useful for exploring data and making informed decisions. The heatmap quickly shows patterns and dependencies between features, which can help with data analysis and modeling. It's especially helpful for hotel booking analysis.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that longer lead times may lead to more cancellations. There are many stay_week_nights and more adults than other guests. Guests who make more special requests are less likely to cancel. Lead times for bookings may have slightly increased over the years. These insights can guide further analysis and decision-making in the EDA project.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called df_subset with the desired columns
# Replace 'data_columns' with the columns you want to analyze
data_columns = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'total_guests', 'Average_daily_rate', 'total_of_special_requests']

# Create the pair plot
sns.pairplot(Hotel_df[data_columns])
plt.title('Pair Plot')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the Pair Plot chart to see how different variables in the dataset relate to each other. It's great for looking at a few numerical variables and finding patterns or connections between them. This will help me make better decisions when analyzing hotel bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The lead time for most of the customers is below 300 and mostly for those who stays_in_week_nights
#
# adr in all segments are below 1000
#
# total_guests in each group ( including all types of guest - adults, child , babies) are less than 10
#
# no. of guests stays in week nights is higher than no, of guest stays in weekend nights

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Drawing from the EDA project, we have compiled a list of recommendations to help our client achieve their business objectives.
#
# 1. Promote City Hotel's popularity by investing more in marketing and promotions to attract guests.
#
# 2. Enhance revenue generation by implementing dynamic pricing strategies and creating attractive packages and offers.
#
# 3. Target online travel agencies to increase visibility and bookings.
#
# 4. Improve customer experience by meeting the needs of corporate travelers and offering personalized experiences and loyalty rewards.
#
# 5. Promote Resort Hotel's unique offerings to attract vacationers seeking relaxation and enjoyable experiences.
#
# 6. Strategically allocate resources and promote preferred room types to optimize bookings and revenue.
#
# 7. Manage lead time by providing special offers or incentives to guests who book in advance.
#
# 8. Customize meal offerings to align with customer preferences and enhance guest satisfaction.
#
# 9. Segment the market and create targeted marketing campaigns for different customer groups.
#
# 10. Focus on peak months to attract more guests during the popular vacation season.
#
# 11. Strengthen relationships with top agents to continue driving high bookings.
#
# 12. Enhance direct booking channels by offering competitive rates, special offers, and a seamless booking experience on their website.
#
# 13. Improve customer loyalty by introducing loyalty programs, offering rewards, or providing exclusive benefits to returning guests.
#
# 14. Customize offerings and services to cater to the preferences of guests.
#
# 15. Create targeted promotions and packages for guests seeking extended stays or weekend getaways.
#
# By implementing these strategies, the client can improve guest satisfaction, increase bookings, optimize revenue, and achieve their business objectives.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Hotel Booking Analysis EDA project aimed to gain insights into the hotel booking dataset, consisting of information related to two types of hotels, City Hotel and Resort Hotel. The dataset was thoroughly analyzed and visualized to extract valuable information, which can aid in making data-driven decisions to optimize business operations and enhance customer experience.
#
# Key Insights:
#
# •	Preference for City Hotel:
#
# The analysis revealed that City Hotels have a higher number of bookings, revenue, and average daily rates compared to Resort Hotels. This suggests that City Hotels are more popular among guests and attract a larger customer base.
#
# •	Seasonal Variation:
#
#  Both hotels experience fluctuations in guest numbers throughout the year, with August being the peak month for bookings and January being the lowest. April, May, and June also showed significant guest numbers, indicating popular vacation periods.
#
# •	Guest Demographics:
#
# The analysis provided insights into the preferred meal plans, room types, and total guests for bookings. "Bed and Breakfast" meal plan and Room Type 'A' were the most popular choices among guests.
#
# •	Cancellation Trends:
#
# City Hotel had a higher percentage of canceled bookings compared to Resort Hotel. Understanding the reasons behind cancellations can help in improving customer satisfaction and optimizing booking strategies
# .
# •	Lead Time and Revenue:
#
#  The analysis indicated that longer lead times might be associated with a higher likelihood of cancellations. Both hotels generated substantial revenue, with City Hotel's revenue slightly higher.
#
# •	Distribution Channels:
#
# Travel Agency/Tour Operator was the most prominent booking distribution channel for both hotels, while direct bookings had a higher revenue share for Resort Hotel.
#
# •	Customer Segmentation:
#
#  Understanding customer preference s and booking patterns can enable targeted marketing efforts to cater to specific guest segments effectively.
# Recommendations: Based on the insights gained from the analysis, the following recommendations are made:
#
# •	Marketing and Promotions:
#
#  City Hotel can invest in targeted marketing campaigns to further leverage its popularity and attract more guests. Resort Hotel can focus on promoting its unique offerings, such as leisure amenities and scenic locations.
#
# •	Customer Experience Enhancement:
#
# Analyzing reasons for cancellations and addressing customer concerns can help improve guest satisfaction and reduce cancellations. Personalized experiences, loyalty programs, and direct booking incentives can be introduced to enhance customer loyalty.
#
# •	Strategic Partnerships:
#
#  Strengthening partnerships with top-performing agents and online travel agencies can help drive more bookings and revenue for both hotels.
#
# •	Seasonal Promotions:
#
#  Creating targeted promotions during peak months can attract more guests during popular vacation periods and maximize revenue.
#
# •	Lead Time Management:
#
#  Managing lead times effectively can reduce cancellations. Offering special deals to guests who book in advance can incentivize early bookings.
#
# •	Direct Bookings:
#
#  Focusing on enhancing direct booking channels can lead to higher profit margins and reduce dependency on third-party agents.
#
# •	Customer Segmentation Strategies:
#
# Tailoring marketing efforts for different customer segments can improve engagement and booking rates.
#
# •	Customer Loyalty Programs:
# Implementing customer loyalty programs can encourage repeat bookings and foster a loyal customer base.
#
# •	Optimize Room Allocation:
#  Analyzing room type preferences can help optimize room allocation and pricing strategies.
#
# •	Adapt to Market Trends:
#
#  Continuous monitoring of market trends and customer preferences will enable the hotels to adapt their strategies and offerings to remain competitive.
# By implementing these recommendations, the hotel management can improve guest satisfaction, increase bookings and revenue, and establish a strong presence in the highly competitive hospitality industry.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
